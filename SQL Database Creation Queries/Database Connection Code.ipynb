# %%
import psycopg2
import pandas as pd
from sqlalchemy import create_engine

# %%
# follows django database settings format, replace with your own settings
DATABASES = {
    'PostgreSQL15':{
        'NAME': 'KMVM_Bootcamp_Final_Project',
        'USER': 'postgres',
        'PASSWORD': 'password123',
        'HOST': 'localhost',
        'PORT': 5432,
    },
}

# choose the database to use
db = DATABASES['PostgreSQL15']

# construct an engine connection string
engine_string = "postgresql+psycopg2://{user}:{password}@{host}:{port}/{database}".format(
    user = db['USER'],
    password = db['PASSWORD'],
    host = db['HOST'],
    port = db['PORT'],
    database = db['NAME'],
)

# create sqlalchemy engine
engine = create_engine(engine_string)

# read a table from database into pandas dataframe, replace "tablename" with your table name
wake_county_df = pd.read_sql_table('zillow_wake_county',engine)

# %%
# Print df
wake_county_df
# Out:
#           date_sold  property_type  lot_area_value  \
# 0     1682665200000  SINGLE_FAMILY        0.920000
# 1     1682665200000  SINGLE_FAMILY        0.350000
# 2     1682665200000  SINGLE_FAMILY        0.429982
# 3     1682665200000  SINGLE_FAMILY        0.260000
# 4     1682665200000  SINGLE_FAMILY        0.920000
# ...             ...            ...             ...
# 4535  1646035200000  SINGLE_FAMILY        0.250000
# 4536  1646035200000  SINGLE_FAMILY     9583.000000
# 4537  1646035200000  SINGLE_FAMILY     5662.800000
# 4538  1645776000000  SINGLE_FAMILY        1.720000
# 4539  1645776000000  SINGLE_FAMILY        1.720000
#
#                                            address    variable_data  \
# 0          7525 Matherly Dr, Wake Forest, NC 27587  Sold 04/28/2023
# 1         132 W Holding Ave, Wake Forest, NC 27587  Sold 04/28/2023
# 2           2809 Stirrup Ct, Wake Forest, NC 27587  Sold 04/28/2023
# 3         900 Finchurch Cir, Wake Forest, NC 27587  Sold 04/28/2023
# ...

# %%
# read a table from database into pandas dataframe, replace "tablename" with your table name
durham_county_df = pd.read_sql_table('zillow_durham_county',engine)

# %%
# Print df
durham_county_df
# Out:
#           date_sold  property_type  lot_area_value  \
# 0     1683874800000  SINGLE_FAMILY           2.000
# 1     1683788400000  SINGLE_FAMILY           0.310
# 2     1683788400000  SINGLE_FAMILY        8276.400
# 3     1683702000000  SINGLE_FAMILY           0.470
# 4     1683529200000  SINGLE_FAMILY           0.510
# ...             ...            ...             ...
# 4303  1641974400000  SINGLE_FAMILY           0.480
# 4304  1641974400000  SINGLE_FAMILY        8276.400
# 4305  1641974400000  SINGLE_FAMILY        8276.400
# 4306  1641888000000  SINGLE_FAMILY           0.326
# 4307  1641888000000  SINGLE_FAMILY           0.413
#
#                                   address    variable_data variale_data_2  \
# 0         1414 Mason Rd, Durham, NC 27712  Sold 05/12/2023  RECENTLY_SOLD
# 1     3015 Elk Ridge Rd, Durham, NC 27712  Sold 05/11/2023  RECENTLY_SOLD
# 2       417 Birchrun Dr, Durham, NC 27712  Sold 05/11/2023  RECENTLY_SOLD
# ...

# %%
# Save file as csv
wake_county_df.to_csv("wake_county.csv", index=True, encoding = 'utf8')
durham_county_df.to_csv("durham_county.csv", index=True, encoding = 'utf8')
