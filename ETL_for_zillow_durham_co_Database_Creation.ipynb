# %%
# Import Dependencies
import pandas as pd

# %%
# Load in properties_2016
zillow_durham_co = "Resources/zillow_durham_co.csv"

# %%
# Read zillow durham co into dataframe
zillow_durham_co = pd.read_csv(zillow_durham_co)
zillow_durham_co_df = zillow_durham_co
#zillow_durham_co_df.head()

# %%
# Check to see df loaded correctly
zillow_durham_co_df.head()
# Out:
#    props.dateSold props.propertyType  props.lotAreaValue  \
# 0   1683874800000      SINGLE_FAMILY                2.00
# 1   1683788400000      SINGLE_FAMILY                0.31
# 2   1683788400000      SINGLE_FAMILY             8276.40
# 3   1683702000000      SINGLE_FAMILY                0.47
# 4   1683529200000      SINGLE_FAMILY                0.51
#
#                          props.address props.variableData.text  \
# 0      1414 Mason Rd, Durham, NC 27712         Sold 05/12/2023
# 1  3015 Elk Ridge Rd, Durham, NC 27712         Sold 05/11/2023
# 2    417 Birchrun Dr, Durham, NC 27712         Sold 05/11/2023
# 3    115 November Dr, Durham, NC 27712         Sold 05/10/2023
# 4   6107 Snowhill Dr, Durham, NC 27712         Sold 05/08/2023
#
#   props.variableData.type  props.zestimate  \
# 0           RECENTLY_SOLD         210700.0
# 1           RECENTLY_SOLD         520900.0
# 2           RECENTLY_SOLD         357313.0
# 3           RECENTLY_SOLD        1296900.0
# 4           RECENTLY_SOLD         632500.0
#
#                                         props.imgSrc  props.price  \
# 0  https://photos.zillowstatic.com/fp/e511948a35a...       225000
# 1  https://photos.zillowstatic.com/fp/d6b616c3c5e...       500000
# 2  https://photos.zillowstatic.com/fp/02bd038fe0b...       376000
# 3  https://photos.zillowstatic.com/fp/61e92cc8e12...      1295000
# 4  https://photos.zillowstatic.com/fp/844b052b032...       632000
#
#    props.bedrooms  ... props.listingStatus  props.zpid  props.rentZestimate  \
# 0               2  ...       RECENTLY_SOLD    50025450                 1563
# 1               4  ...       RECENTLY_SOLD    50017911                 2826
# 2               3  ...       RECENTLY_SOLD   108265022                 1800
# 3               4  ...       RECENTLY_SOLD    98210952                 6488
# 4               4  ...       RECENTLY_SOLD    98219039                 2792
#
#   props.daysOnZillow  props.bathrooms  props.livingArea  props.country  \
# 0                 -1              1.0            1346.0            USA
# 1                 -1              3.0            2175.0            USA
# 2                 -1              2.0            1441.0            USA
# 3                 -1              5.0            4298.0            USA
# 4                 -1              3.0            2859.0            USA
#
#    props.currency  props.lotAreaUnit props.hasImage
# 0             USD              acres           True
# 1             USD              acres           True
# 2             USD               sqft           True
# 3             USD              acres           True
# 4             USD              acres           True
#
# [5 rows x 23 columns]

# %%
# Use describe 
zillow_durham_co_df.describe
# Out:
# <bound method NDFrame.describe of       props.dateSold props.propertyType  props.lotAreaValue  \
# 0      1683874800000      SINGLE_FAMILY               2.000
# 1      1683788400000      SINGLE_FAMILY               0.310
# 2      1683788400000      SINGLE_FAMILY            8276.400
# 3      1683702000000      SINGLE_FAMILY               0.470
# 4      1683529200000      SINGLE_FAMILY               0.510
# ...              ...                ...                 ...
# 4303   1641974400000      SINGLE_FAMILY               0.480
# 4304   1641974400000      SINGLE_FAMILY            8276.400
# 4305   1641974400000      SINGLE_FAMILY            8276.400
# 4306   1641888000000      SINGLE_FAMILY               0.326
# 4307   1641888000000      SINGLE_FAMILY               0.413
#
#                             props.address props.variableData.text  \
# 0         1414 Mason Rd, Durham, NC 27712         Sold 05/12/2023
# 1     3015 Elk Ridge Rd, Durham, NC 27712         Sold 05/11/2023
# 2       417 Birchrun Dr, Durham, NC 27712         Sold 05/11/2023
# 3       115 November Dr, Durham, NC 27712         Sold 05/10/2023
# 4      6107 Snowhill Dr, Durham, NC 27712         Sold 05/08/2023
# ...                                   ...                     ...
# 4303      4 S Nipper Ct, Durham, NC 27704         Sold 01/12/2022
# 4304   2004 Buffalo Way, Durham, NC 27704         Sold 01/12/2022
# 4305      3008 Kenan Rd, Durham, NC 27704         Sold 01/12/2022
# 4306    703 W Carver St, Durham, NC 27704         Sold 01/11/2022
# 4307   805 Sanderson Dr, Durham, NC 27704         Sold 01/11/2022
#
#      props.variableData.type  props.zestimate  \
# 0              RECENTLY_SOLD         210700.0
# 1              RECENTLY_SOLD         520900.0
# 2              RECENTLY_SOLD         357313.0
# 3              RECENTLY_SOLD        1296900.0
# 4              RECENTLY_SOLD         632500.0
# ...                      ...              ...
# 4303           RECENTLY_SOLD         298800.0
# 4304           RECENTLY_SOLD         301600.0
# 4305           RECENTLY_SOLD         492800.0
# 4306           RECENTLY_SOLD         348300.0
# 4307           RECENTLY_SOLD         377300.0
#
#                                            props.imgSrc  props.price  \
# 0     https://photos.zillowstatic.com/fp/e511948a35a...       225000
# 1     https://photos.zillowstatic.com/fp/d6b616c3c5e...       500000
# 2     https://photos.zillowstatic.com/fp/02bd038fe0b...       376000
# 3     https://photos.zillowstatic.com/fp/61e92cc8e12...      1295000
# 4     https://photos.zillowstatic.com/fp/844b052b032...       632000
# ...                                                 ...          ...
# 4303  https://photos.zillowstatic.com/fp/697f70fb343...       245000
# 4304  https://photos.zillowstatic.com/fp/788db1bbbdd...       270000
# 4305  https://photos.zillowstatic.com/fp/98eedd159e7...       470000
# 4306  https://photos.zillowstatic.com/fp/1ead45e8823...       332000
# 4307  https://photos.zillowstatic.com/fp/959b0ce6758...       360000
#
#       props.bedrooms  ... props.listingStatus  props.zpid  \
# 0                  2  ...       RECENTLY_SOLD    50025450
# 1                  4  ...       RECENTLY_SOLD    50017911
# 2                  3  ...       RECENTLY_SOLD   108265022
# 3                  4  ...       RECENTLY_SOLD    98210952
# 4                  4  ...       RECENTLY_SOLD    98219039
# ...              ...  ...                 ...         ...
# 4303               3  ...       RECENTLY_SOLD    50007516
# 4304               3  ...       RECENTLY_SOLD    61727149
# 4305               3  ...       RECENTLY_SOLD   299118033
# 4306               3  ...       RECENTLY_SOLD    49986974
# 4307               3  ...       RECENTLY_SOLD    50014784
#
#       props.rentZestimate props.daysOnZillow  props.bathrooms  \
# 0                    1563                 -1              1.0
# 1                    2826                 -1              3.0
# 2                    1800                 -1              2.0
# 3                    6488                 -1              5.0
# 4                    2792                 -1              3.0
# ...                   ...                ...              ...
# 4303                 1594                 -1              2.0
# 4304                 1645                 -1              3.0
# 4305                 2094                 -1              3.0
# 4306                 2028                 -1              2.0
# 4307                 1825                 -1              2.0
#
#       props.livingArea  props.country  props.currency  props.lotAreaUnit  \
# 0               1346.0            USA             USD              acres
# 1               2175.0            USA             USD              acres
# 2               1441.0            USA             USD               sqft
# 3               4298.0            USA             USD              acres
# 4               2859.0            USA             USD              acres
# ...                ...            ...             ...                ...
# 4303            1310.0            USA             USD              acres
# 4304            1263.0            USA             USD               sqft
# 4305            1772.0            USA             USD               sqft
# 4306            1408.0            USA             USD              acres
# 4307            1693.0            USA             USD              acres
#
#      props.hasImage
# 0              True
# 1              True
# 2              True
# 3              True
# 4              True
# ...             ...
# 4303           True
# 4304           True
# 4305           True
# 4306           True
# 4307           True
#
# [4308 rows x 23 columns]>

# %%
# Check to see the data types of the df
zillow_durham_co_df.dtypes
# Out:
# props.dateSold                   int64
# props.propertyType              object
# props.lotAreaValue             float64
# props.address                   object
# props.variableData.text         object
# props.variableData.type         object
# props.zestimate                float64
# props.imgSrc                    object
# props.price                      int64
# props.bedrooms                   int64
# props.contingentListingType     object
# props.longitude                float64
# props.latitude                 float64
# props.listingStatus             object
# props.zpid                       int64
# props.rentZestimate              int64
# props.daysOnZillow               int64
# props.bathrooms                float64
# props.livingArea               float64
# props.country                   object
# props.currency                  object
# props.lotAreaUnit               object
# props.hasImage                  object
# dtype: object

# %%
# Check for missing values
zillow_durham_co_df.count()
# Out:
# props.dateSold                 4308
# props.propertyType             4308
# props.lotAreaValue             4308
# props.address                  4308
# props.variableData.text        4308
# props.variableData.type        4308
# props.zestimate                4307
# props.imgSrc                   4308
# props.price                    4308
# props.bedrooms                 4308
# props.contingentListingType      22
# props.longitude                4301
# props.latitude                 4301
# props.listingStatus            4308
# props.zpid                     4308
# props.rentZestimate            4308
# props.daysOnZillow             4308
# props.bathrooms                4308
# props.livingArea               4303
# props.country                  4308
# props.currency                 4308
# props.lotAreaUnit              4308
# props.hasImage                 3783
# dtype: int64

# %%
# Drop 'props.contingentListingType' & 'props.hasImage' 
zillow_durham_co_df_clean = zillow_durham_co_df.drop(['props.contingentListingType', 'props.hasImage'], axis=1)
zillow_durham_co_df_clean.head()
# Out:
#    props.dateSold props.propertyType  props.lotAreaValue  \
# 0   1683874800000      SINGLE_FAMILY                2.00
# 1   1683788400000      SINGLE_FAMILY                0.31
# 2   1683788400000      SINGLE_FAMILY             8276.40
# 3   1683702000000      SINGLE_FAMILY                0.47
# 4   1683529200000      SINGLE_FAMILY                0.51
#
#                          props.address props.variableData.text  \
# 0      1414 Mason Rd, Durham, NC 27712         Sold 05/12/2023
# 1  3015 Elk Ridge Rd, Durham, NC 27712         Sold 05/11/2023
# 2    417 Birchrun Dr, Durham, NC 27712         Sold 05/11/2023
# 3    115 November Dr, Durham, NC 27712         Sold 05/10/2023
# 4   6107 Snowhill Dr, Durham, NC 27712         Sold 05/08/2023
#
#   props.variableData.type  props.zestimate  \
# 0           RECENTLY_SOLD         210700.0
# 1           RECENTLY_SOLD         520900.0
# 2           RECENTLY_SOLD         357313.0
# 3           RECENTLY_SOLD        1296900.0
# 4           RECENTLY_SOLD         632500.0
#
#                                         props.imgSrc  props.price  \
# 0  https://photos.zillowstatic.com/fp/e511948a35a...       225000
# 1  https://photos.zillowstatic.com/fp/d6b616c3c5e...       500000
# 2  https://photos.zillowstatic.com/fp/02bd038fe0b...       376000
# 3  https://photos.zillowstatic.com/fp/61e92cc8e12...      1295000
# 4  https://photos.zillowstatic.com/fp/844b052b032...       632000
#
#    props.bedrooms  ...  props.latitude  props.listingStatus props.zpid  \
# 0               2  ...       36.126660        RECENTLY_SOLD   50025450
# 1               4  ...       36.064587        RECENTLY_SOLD   50017911
# 2               3  ...       36.096012        RECENTLY_SOLD  108265022
# 3               4  ...       36.075172        RECENTLY_SOLD   98210952
# 4               4  ...       36.107597        RECENTLY_SOLD   98219039
#
#    props.rentZestimate  props.daysOnZillow  props.bathrooms  props.livingArea  \
# 0                 1563                  -1              1.0            1346.0
# 1                 2826                  -1              3.0            2175.0
# 2                 1800                  -1              2.0            1441.0
# 3                 6488                  -1              5.0            4298.0
# 4                 2792                  -1              3.0            2859.0
#
#    props.country props.currency props.lotAreaUnit
# 0            USA            USD             acres
# 1            USA            USD             acres
# 2            USA            USD              sqft
# 3            USA            USD             acres
# 4            USA            USD             acres
#
# [5 rows x 21 columns]

# %%
# Check count
zillow_durham_co_df_clean.count()
# Out:
# props.dateSold             4308
# props.propertyType         4308
# props.lotAreaValue         4308
# props.address              4308
# props.variableData.text    4308
# props.variableData.type    4308
# props.zestimate            4307
# props.imgSrc               4308
# props.price                4308
# props.bedrooms             4308
# props.longitude            4301
# props.latitude             4301
# props.listingStatus        4308
# props.zpid                 4308
# props.rentZestimate        4308
# props.daysOnZillow         4308
# props.bathrooms            4308
# props.livingArea           4303
# props.country              4308
# props.currency             4308
# props.lotAreaUnit          4308
# dtype: int64

# %%
# Check for missing values
zillow_durham_co_df_clean.isnull().sum()
# Out:
# props.dateSold             0
# props.propertyType         0
# props.lotAreaValue         0
# props.address              0
# props.variableData.text    0
# props.variableData.type    0
# props.zestimate            1
# props.imgSrc               0
# props.price                0
# props.bedrooms             0
# props.longitude            7
# props.latitude             7
# props.listingStatus        0
# props.zpid                 0
# props.rentZestimate        0
# props.daysOnZillow         0
# props.bathrooms            0
# props.livingArea           5
# props.country              0
# props.currency             0
# props.lotAreaUnit          0
# dtype: int64

# %%
#Drop the nulls
zillow_durham_co_df_clean=zillow_durham_co_df_clean.dropna()

# %%
# Check for missing values
zillow_durham_co_df_clean.isnull().sum()
# Out:
# props.dateSold             0
# props.propertyType         0
# props.lotAreaValue         0
# props.address              0
# props.variableData.text    0
# props.variableData.type    0
# props.zestimate            0
# props.imgSrc               0
# props.price                0
# props.bedrooms             0
# props.longitude            0
# props.latitude             0
# props.listingStatus        0
# props.zpid                 0
# props.rentZestimate        0
# props.daysOnZillow         0
# props.bathrooms            0
# props.livingArea           0
# props.country              0
# props.currency             0
# props.lotAreaUnit          0
# dtype: int64

# %%
# Split the address into additional home address, city, state, and zip columns
zillow_durham_co_df_clean[['props.mail_address', 'props.city', 'props.state']]= zillow_durham_co_df_clean['props.address'].str.split(',', expand=True)

# %%
zillow_durham_co_df_clean
# Out:
#       props.dateSold props.propertyType  props.lotAreaValue  \
# 0      1683874800000      SINGLE_FAMILY               2.000
# 1      1683788400000      SINGLE_FAMILY               0.310
# 2      1683788400000      SINGLE_FAMILY            8276.400
# 3      1683702000000      SINGLE_FAMILY               0.470
# 4      1683529200000      SINGLE_FAMILY               0.510
# ...              ...                ...                 ...
# 4303   1641974400000      SINGLE_FAMILY               0.480
# 4304   1641974400000      SINGLE_FAMILY            8276.400
# 4305   1641974400000      SINGLE_FAMILY            8276.400
# 4306   1641888000000      SINGLE_FAMILY               0.326
# 4307   1641888000000      SINGLE_FAMILY               0.413
#
#                             props.address props.variableData.text  \
# 0         1414 Mason Rd, Durham, NC 27712         Sold 05/12/2023
# 1     3015 Elk Ridge Rd, Durham, NC 27712         Sold 05/11/2023
# 2       417 Birchrun Dr, Durham, NC 27712         Sold 05/11/2023
# 3       115 November Dr, Durham, NC 27712         Sold 05/10/2023
# 4      6107 Snowhill Dr, Durham, NC 27712         Sold 05/08/2023
# ...                                   ...                     ...
# 4303      4 S Nipper Ct, Durham, NC 27704         Sold 01/12/2022
# 4304   2004 Buffalo Way, Durham, NC 27704         Sold 01/12/2022
# 4305      3008 Kenan Rd, Durham, NC 27704         Sold 01/12/2022
# 4306    703 W Carver St, Durham, NC 27704         Sold 01/11/2022
# 4307   805 Sanderson Dr, Durham, NC 27704         Sold 01/11/2022
#
#      props.variableData.type  props.zestimate  \
# 0              RECENTLY_SOLD         210700.0
# 1              RECENTLY_SOLD         520900.0
# 2              RECENTLY_SOLD         357313.0
# 3              RECENTLY_SOLD        1296900.0
# 4              RECENTLY_SOLD         632500.0
# ...                      ...              ...
# 4303           RECENTLY_SOLD         298800.0
# 4304           RECENTLY_SOLD         301600.0
# 4305           RECENTLY_SOLD         492800.0
# 4306           RECENTLY_SOLD         348300.0
# 4307           RECENTLY_SOLD         377300.0
#
#                                            props.imgSrc  props.price  \
# 0     https://photos.zillowstatic.com/fp/e511948a35a...       225000
# 1     https://photos.zillowstatic.com/fp/d6b616c3c5e...       500000
# 2     https://photos.zillowstatic.com/fp/02bd038fe0b...       376000
# 3     https://photos.zillowstatic.com/fp/61e92cc8e12...      1295000
# 4     https://photos.zillowstatic.com/fp/844b052b032...       632000
# ...                                                 ...          ...
# 4303  https://photos.zillowstatic.com/fp/697f70fb343...       245000
# 4304  https://photos.zillowstatic.com/fp/788db1bbbdd...       270000
# 4305  https://photos.zillowstatic.com/fp/98eedd159e7...       470000
# 4306  https://photos.zillowstatic.com/fp/1ead45e8823...       332000
# 4307  https://photos.zillowstatic.com/fp/959b0ce6758...       360000
#
#       props.bedrooms  ...  props.rentZestimate  props.daysOnZillow  \
# 0                  2  ...                 1563                  -1
# 1                  4  ...                 2826                  -1
# 2                  3  ...                 1800                  -1
# 3                  4  ...                 6488                  -1
# 4                  4  ...                 2792                  -1
# ...              ...  ...                  ...                 ...
# 4303               3  ...                 1594                  -1
# 4304               3  ...                 1645                  -1
# 4305               3  ...                 2094                  -1
# 4306               3  ...                 2028                  -1
# 4307               3  ...                 1825                  -1
#
#      props.bathrooms  props.livingArea  props.country  props.currency  \
# 0                1.0            1346.0            USA             USD
# 1                3.0            2175.0            USA             USD
# 2                2.0            1441.0            USA             USD
# 3                5.0            4298.0            USA             USD
# 4                3.0            2859.0            USA             USD
# ...              ...               ...            ...             ...
# 4303             2.0            1310.0            USA             USD
# 4304             3.0            1263.0            USA             USD
# 4305             3.0            1772.0            USA             USD
# 4306             2.0            1408.0            USA             USD
# 4307             2.0            1693.0            USA             USD
#
#       props.lotAreaUnit  props.mail_address props.city props.state
# 0                 acres       1414 Mason Rd     Durham    NC 27712
# 1                 acres   3015 Elk Ridge Rd     Durham    NC 27712
# 2                  sqft     417 Birchrun Dr     Durham    NC 27712
# 3                 acres     115 November Dr     Durham    NC 27712
# 4                 acres    6107 Snowhill Dr     Durham    NC 27712
# ...                 ...                 ...        ...         ...
# 4303              acres       4 S Nipper Ct     Durham    NC 27704
# 4304               sqft    2004 Buffalo Way     Durham    NC 27704
# 4305               sqft       3008 Kenan Rd     Durham    NC 27704
# 4306              acres     703 W Carver St     Durham    NC 27704
# 4307              acres    805 Sanderson Dr     Durham    NC 27704
#
# [4296 rows x 24 columns]

# %%
# Strip the white space from the props.state column
zillow_durham_co_df_clean['props.state']=zillow_durham_co_df_clean['props.state'].str.strip()

# %%
# Separate the state and zip code into two columns
zillow_durham_co_df_clean[['props.state', 'props.zipcode']]= zillow_durham_co_df_clean['props.state'].str.split(' ', expand=True)

# %%
# Drop the original address column and reorder
zillow_durham_co_df_clean = zillow_durham_co_df_clean.reindex(columns=['props.dateSold', 'props.propertyType', 'props.lotAreaValue', 'props.mail_address', 'props.city','props.state', 'props.zipcode', 'props.variableData.text', 'props.variableData.type', 'props.zestimate', 'props.imgSrc', 'props.price', 'props.bedrooms', 'props.daysOnZillow', 'props.bathrooms', 'props.livingArea', 'props.country', 'props.currency', 'props.lotAreaUnit'])

# %%
# Check the splits
zillow_durham_co_df_clean.head()
# Out:
#    props.dateSold props.propertyType  props.lotAreaValue props.mail_address  \
# 0   1683874800000      SINGLE_FAMILY                2.00      1414 Mason Rd
# 1   1683788400000      SINGLE_FAMILY                0.31  3015 Elk Ridge Rd
# 2   1683788400000      SINGLE_FAMILY             8276.40    417 Birchrun Dr
# 3   1683702000000      SINGLE_FAMILY                0.47    115 November Dr
# 4   1683529200000      SINGLE_FAMILY                0.51   6107 Snowhill Dr
#
#   props.city props.state props.zipcode props.variableData.text  \
# 0     Durham          NC         27712         Sold 05/12/2023
# 1     Durham          NC         27712         Sold 05/11/2023
# 2     Durham          NC         27712         Sold 05/11/2023
# 3     Durham          NC         27712         Sold 05/10/2023
# 4     Durham          NC         27712         Sold 05/08/2023
#
#   props.variableData.type  props.zestimate  \
# 0           RECENTLY_SOLD         210700.0
# 1           RECENTLY_SOLD         520900.0
# 2           RECENTLY_SOLD         357313.0
# 3           RECENTLY_SOLD        1296900.0
# 4           RECENTLY_SOLD         632500.0
#
#                                         props.imgSrc  props.price  \
# 0  https://photos.zillowstatic.com/fp/e511948a35a...       225000
# 1  https://photos.zillowstatic.com/fp/d6b616c3c5e...       500000
# 2  https://photos.zillowstatic.com/fp/02bd038fe0b...       376000
# 3  https://photos.zillowstatic.com/fp/61e92cc8e12...      1295000
# 4  https://photos.zillowstatic.com/fp/844b052b032...       632000
#
#    props.bedrooms  props.daysOnZillow  props.bathrooms  props.livingArea  \
# 0               2                  -1              1.0            1346.0
# 1               4                  -1              3.0            2175.0
# 2               3                  -1              2.0            1441.0
# 3               4                  -1              5.0            4298.0
# 4               4                  -1              3.0            2859.0
#
#   props.country props.currency props.lotAreaUnit
# 0           USA            USD             acres
# 1           USA            USD             acres
# 2           USA            USD              sqft
# 3           USA            USD             acres
# 4           USA            USD             acres

# %%
# Show the coorelation between living area to price
zillow_durham_co_df_clean.plot.scatter(x='props.livingArea', y='props.price')
# Out:
# <AxesSubplot:xlabel='props.livingArea', ylabel='props.price'>

# %%
# Show the coorelation between bathrooms to bedrooms
zillow_durham_co_df_clean.plot.scatter(x='props.bedrooms', y='props.bathrooms')
# Out:
# <AxesSubplot:xlabel='props.bedrooms', ylabel='props.bathrooms'>

# %%
# For visualizations
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from collections import Counter
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler,OneHotEncoder
from IPython.display import display
import seaborn as sb # visualization

sb.heatmap(zillow_durham_co_df_clean.corr(), annot = True, cmap = 'magma')

plt.savefig('heatmap.png')
plt.show()
