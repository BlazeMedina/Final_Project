# %%
# Import Dependencies
import pandas as pd

# %%
# Load in properties_2016
zillow_durham_co = "Resources/zillow_durham_co.csv"

# %%
# Read properties_2016 into dataframe
zillow_durham_co = pd.read_csv(zillow_durham_co)
zillow_durham_co_df = zillow_durham_co
zillow_durham_co_df
# Out:
#       props.dateSold props.propertyType  props.lotAreaValue  \
# 0      1683874800000      SINGLE_FAMILY               2.000
# 1      1683788400000      SINGLE_FAMILY               0.310
# 2      1683788400000      SINGLE_FAMILY            8276.400
# 3      1683702000000      SINGLE_FAMILY               0.470
# 4      1683529200000      SINGLE_FAMILY               0.510
# ...              ...                ...                 ...
# 4303   1641974400000      SINGLE_FAMILY               0.480
# 4304   1641974400000      SINGLE_FAMILY            8276.400
# 4305   1641974400000      SINGLE_FAMILY            8276.400
# 4306   1641888000000      SINGLE_FAMILY               0.326
# 4307   1641888000000      SINGLE_FAMILY               0.413
#
#                             props.address props.variableData.text  \
# 0         1414 Mason Rd, Durham, NC 27712         Sold 05/12/2023
# 1     3015 Elk Ridge Rd, Durham, NC 27712         Sold 05/11/2023
# ...

# %%
# Get description of dataframe
zillow_durham_co_df.describe
# Out:
# <bound method NDFrame.describe of       props.dateSold props.propertyType  props.lotAreaValue  \
# 0      1683874800000      SINGLE_FAMILY               2.000
# 1      1683788400000      SINGLE_FAMILY               0.310
# 2      1683788400000      SINGLE_FAMILY            8276.400
# 3      1683702000000      SINGLE_FAMILY               0.470
# 4      1683529200000      SINGLE_FAMILY               0.510
# ...              ...                ...                 ...
# 4303   1641974400000      SINGLE_FAMILY               0.480
# 4304   1641974400000      SINGLE_FAMILY            8276.400
# 4305   1641974400000      SINGLE_FAMILY            8276.400
# 4306   1641888000000      SINGLE_FAMILY               0.326
# 4307   1641888000000      SINGLE_FAMILY               0.413
#
#                             props.address props.variableData.text  \
# 0         1414 Mason Rd, Durham, NC 27712         Sold 05/12/2023
# 1     3015 Elk Ridge Rd, Durham, NC 27712         Sold 05/11/2023
# ...

# %%
# Get datatypes
zillow_durham_co_df.dtypes
# Out:
# props.dateSold                   int64
# props.propertyType              object
# props.lotAreaValue             float64
# props.address                   object
# props.variableData.text         object
# props.variableData.type         object
# props.zestimate                float64
# props.imgSrc                    object
# props.price                      int64
# props.bedrooms                   int64
# props.contingentListingType     object
# props.longitude                float64
# props.latitude                 float64
# props.listingStatus             object
# props.zpid                       int64
# props.rentZestimate              int64
# props.daysOnZillow               int64
# props.bathrooms                float64
# props.livingArea               float64
# props.country                   object
# props.currency                  object
# props.lotAreaUnit               object
# props.hasImage                  object
# dtype: object

# %%
# Counting Nan/null in above columns
print("\nCount total Nan at each column in a Dataframe : \n\n", zillow_durham_co_df.isnull().sum())
# Out:
# Count total Nan at each column in a Dataframe :
#
#  props.dateSold                    0
# props.propertyType                0
# props.lotAreaValue                0
# props.address                     0
# props.variableData.text           0
# props.variableData.type           0
# props.zestimate                   1
# props.imgSrc                      0
# props.price                       0
# props.bedrooms                    0
# props.contingentListingType    4286
# props.longitude                   7
# props.latitude                    7
# props.listingStatus               0
# props.zpid                        0
# props.rentZestimate               0
# props.daysOnZillow                0
# props.bathrooms                   0
# props.livingArea                  5
# props.country                     0
# props.currency                    0
# props.lotAreaUnit                 0
# props.hasImage                  525
# dtype: int64

# %%
#drop unnecessary columns starting Unnamed: 23,24,25
zillow_durham_co_df = zillow_durham_co_df.drop(columns =['Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29292\3198027958.py in <module>
#       1 #drop unnecessary columns starting Unnamed: 23,24,25
# ----> 2 zillow_durham_co_df = zillow_durham_co_df.drop(columns =['Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25'])
#
# ~\anaconda3\Anaconda_Redownload\envs\PythonData\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\Anaconda_Redownload\envs\PythonData\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# ...

# %%
# Saved file to csv
zillow_durham_co_df.to_csv("zillow_durham_co_df.csv", index=False, encoding = 'utf8')
