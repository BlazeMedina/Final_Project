# %%
# Import Dependencies
import pandas as pd

# %%
# Load in properties_2016
properties_2016 = "Resources/properties_2016.csv"

# %%
# Read properties_2016 into dataframe
properties_2016 = pd.read_csv((properties_2016), low_memory=False)
#properties_2016 = pd.read_csv(properties_2016)
properties_2016_df = properties_2016
properties_2016_df.head(5)
# Out:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  10754147                    NaN                       NaN           NaN
# 1  10759547                    NaN                       NaN           NaN
# 2  10843547                    NaN                       NaN           NaN
# 3  10859147                    NaN                       NaN           NaN
# 4  10879947                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          0.0         0.0                  NaN                    NaN
# 1          0.0         0.0                  NaN                    NaN
# 2          0.0         0.0                  NaN                    NaN
# 3          0.0         0.0                  3.0                    7.0
# 4          0.0         0.0                  4.0                    NaN
#
#    calculatedbathnbr  decktypeid  ...  numberofstories  fireplaceflag  \
# ...

# %%
properties_2016_df.describe
# Out:
# <bound method NDFrame.describe of           parcelid  airconditioningtypeid  architecturalstyletypeid  \
# 0         10754147                    NaN                       NaN
# 1         10759547                    NaN                       NaN
# 2         10843547                    NaN                       NaN
# 3         10859147                    NaN                       NaN
# 4         10879947                    NaN                       NaN
# ...            ...                    ...                       ...
# 2985212  168176230                    NaN                       NaN
# 2985213   14273630                    NaN                       NaN
# 2985214  168040630                    NaN                       NaN
# 2985215  168040830                    NaN                       NaN
# 2985216  168040430                    NaN                       NaN
#
#          basementsqft  bathroomcnt  bedroomcnt  buildingclasstypeid  \
# ...

# %%
properties_2016_df.dtypes
# Out:
# parcelid                          int64
# airconditioningtypeid           float64
# architecturalstyletypeid        float64
# basementsqft                    float64
# bathroomcnt                     float64
# bedroomcnt                      float64
# buildingclasstypeid             float64
# buildingqualitytypeid           float64
# calculatedbathnbr               float64
# decktypeid                      float64
# finishedfloor1squarefeet        float64
# calculatedfinishedsquarefeet    float64
# finishedsquarefeet12            float64
# finishedsquarefeet13            float64
# finishedsquarefeet15            float64
# finishedsquarefeet50            float64
# finishedsquarefeet6             float64
# fips                            float64
# fireplacecnt                    float64
# fullbathcnt                     float64
# garagecarcnt                    float64
# garagetotalsqft                 float64
# hashottuborspa                   object
# ...

# %%
# Cleaning issue with Object datatype columns
object_columns = properties_2016_df.select_dtypes(include=['object']).columns

#Display columns
print('\nobject columns:\n', object_columns)
# Out:
# object columns:
#  Index(['hashottuborspa', 'propertycountylandusecode', 'propertyzoningdesc',
#        'fireplaceflag', 'taxdelinquencyflag'],
#       dtype='object')

# %%
# Counting Nan/null in above columns
print("\nCount total Nan at each column in a Dataframe : \n\n", properties_2016_df.isnull().sum())
# Out:
# Count total Nan at each column in a Dataframe :
#
#  parcelid                              0
# airconditioningtypeid           2173698
# architecturalstyletypeid        2979156
# basementsqft                    2983589
# bathroomcnt                       11462
# bedroomcnt                        11450
# buildingclasstypeid             2972588
# buildingqualitytypeid           1046729
# calculatedbathnbr                128912
# decktypeid                      2968121
# finishedfloor1squarefeet        2782500
# calculatedfinishedsquarefeet      55565
# finishedsquarefeet12             276033
# finishedsquarefeet13            2977545
# finishedsquarefeet15            2794419
# finishedsquarefeet50            2782500
# finishedsquarefeet6             2963216
# fips                              11437
# fireplacecnt                    2672580
# fullbathcnt                      128912
# garagecarcnt                    2101950
# garagetotalsqft                 2101950
# ...

# %%
# Drop columsn where Nan is dominant (approx. half or more of the data in row)
properties_2016_df = properties_2016_df.drop(['airconditioningtypeid', 'architecturalstyletypeid', 'basementsqft', 'buildingclasstypeid', 'decktypeid', 'finishedfloor1squarefeet', 'finishedsquarefeet12', 'finishedsquarefeet13', 'finishedsquarefeet15', 'finishedsquarefeet50', 'finishedsquarefeet6', 'fireplacecnt', 'garagecarcnt', 'garagetotalsqft', 'hashottuborspa', 'heatingorsystemtypeid', 'poolcnt', 'poolsizesum', 'pooltypeid10', 'pooltypeid2', 'pooltypeid7', 'propertyzoningdesc', 'regionidneighborhood', 'storytypeid', 'threequarterbathnbr', 'typeconstructiontypeid', 'unitcnt', 'yardbuildingsqft17', 'yardbuildingsqft26', 'numberofstories', 'fireplaceflag', 'taxdelinquencyflag', 'taxdelinquencyyear'], axis=1)
properties_2016_df
# Out:
#           parcelid  bathroomcnt  bedroomcnt  buildingqualitytypeid  \
# 0         10754147          0.0         0.0                    NaN
# 1         10759547          0.0         0.0                    NaN
# 2         10843547          0.0         0.0                    NaN
# 3         10859147          0.0         0.0                    7.0
# 4         10879947          0.0         0.0                    NaN
# ...            ...          ...         ...                    ...
# 2985212  168176230          NaN         NaN                    NaN
# 2985213   14273630          NaN         NaN                    NaN
# 2985214  168040630          NaN         NaN                    NaN
# 2985215  168040830          NaN         NaN                    NaN
# 2985216  168040430          NaN         NaN                    NaN
#
#          calculatedbathnbr  calculatedfinishedsquarefeet    fips  fullbathcnt  \
# 0                      NaN                           NaN  6037.0          NaN
# ...

# %%
# Drop rows where longitude is null/NaN
properties_2016_df = properties_2016_df.dropna(subset=['regionidzip'])
properties_2016_df
# Out:
#          parcelid  bathroomcnt  bedroomcnt  buildingqualitytypeid  \
# 0        10754147          0.0         0.0                    NaN
# 1        10759547          0.0         0.0                    NaN
# 2        10843547          0.0         0.0                    NaN
# 3        10859147          0.0         0.0                    7.0
# 4        10879947          0.0         0.0                    NaN
# ...           ...          ...         ...                    ...
# 2973775  11366340          1.0         2.0                    7.0
# 2973776  13010327          3.0         3.0                    4.0
# 2973777  12385768          4.0         4.0                    4.0
# 2973778  11795063          1.0         1.0                    4.0
# 2973779  11818454          0.0         0.0                    NaN
#
#          calculatedbathnbr  calculatedfinishedsquarefeet    fips  fullbathcnt  \
# 0                      NaN                           NaN  6037.0          NaN
# ...

# %%
#Split dataframe due to large size and gitlab limits
properties_2016_df1 = properties_2016_df.iloc[:535000]
properties_2016_df2 = properties_2016_df.iloc[535000:1070000]
properties_2016_df3 = properties_2016_df.iloc[1070000:1605000]
properties_2016_df4 = properties_2016_df.iloc[1605000:2140000]
properties_2016_df5 = properties_2016_df.iloc[2140000:2675000]
properties_2016_df6 = properties_2016_df.iloc[2675000:]

# %%
# Preview dfs
properties_2016_df1
properties_2016_df2
properties_2016_df3
properties_2016_df4
properties_2016_df5
properties_2016_df6
# Out:
#          parcelid  bathroomcnt  bedroomcnt  buildingqualitytypeid  \
# 2677315  17269105          2.0         3.0                    NaN
# 2677316  17269228          2.0         3.0                    NaN
# 2677317  17269466          2.0         3.0                    NaN
# 2677318  17269658          2.0         4.0                    NaN
# 2677319  17269773          2.0         4.0                    NaN
# ...           ...          ...         ...                    ...
# 2973775  11366340          1.0         2.0                    7.0
# 2973776  13010327          3.0         3.0                    4.0
# 2973777  12385768          4.0         4.0                    4.0
# 2973778  11795063          1.0         1.0                    4.0
# 2973779  11818454          0.0         0.0                    NaN
#
#          calculatedbathnbr  calculatedfinishedsquarefeet    fips  fullbathcnt  \
# 2677315                2.0                        1203.0  6111.0          2.0
# ...

# %%
# Saved file to csv
properties_2016_df1.to_csv("properties_2016_cleaned_set1.csv", index=False, encoding = 'utf8')
properties_2016_df2.to_csv("properties_2016_cleaned_set2.csv", index=False, encoding = 'utf8')
properties_2016_df3.to_csv("properties_2016_cleaned_set3.csv", index=False, encoding = 'utf8')
properties_2016_df4.to_csv("properties_2016_cleaned_set4.csv", index=False, encoding = 'utf8')
properties_2016_df5.to_csv("properties_2016_cleaned_set5.csv", index=False, encoding = 'utf8')
properties_2016_df6.to_csv("properties_2016_cleaned_set6.csv", index=False, encoding = 'utf8')
