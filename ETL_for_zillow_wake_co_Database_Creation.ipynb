# %%
# Import Dependencies
import pandas as pd

# %%
# Load in properties_2016
zillow_wake_co = "Resources/zillow_wake_co.csv"

# %%
# Read properties_2016 into dataframe
zillow_wake_co = pd.read_csv(zillow_wake_co)
zillow_wake_co_df = zillow_wake_co
zillow_wake_co_df
# Out:
#       props.dateSold props.propertyType  props.lotAreaValue  \
# 0      1682665200000      SINGLE_FAMILY            0.920000
# 1      1682665200000      SINGLE_FAMILY            0.350000
# 2      1682665200000      SINGLE_FAMILY            0.429982
# 3      1682665200000      SINGLE_FAMILY            0.260000
# 4      1682665200000      SINGLE_FAMILY            0.920000
# ...              ...                ...                 ...
# 4535   1646035200000      SINGLE_FAMILY            0.250000
# 4536   1646035200000      SINGLE_FAMILY         9583.000000
# 4537   1646035200000      SINGLE_FAMILY         5662.800000
# 4538   1645776000000      SINGLE_FAMILY            1.720000
# 4539   1645776000000      SINGLE_FAMILY            1.720000
#
#                                      props.address props.variableData.text  \
# 0          7525 Matherly Dr, Wake Forest, NC 27587         Sold 04/28/2023
# 1         132 W Holding Ave, Wake Forest, NC 27587         Sold 04/28/2023
# ...

# %%
# Get description of dataframe
zillow_wake_co_df.describe
# Out:
# <bound method NDFrame.describe of       props.dateSold props.propertyType  props.lotAreaValue  \
# 0      1682665200000      SINGLE_FAMILY            0.920000
# 1      1682665200000      SINGLE_FAMILY            0.350000
# 2      1682665200000      SINGLE_FAMILY            0.429982
# 3      1682665200000      SINGLE_FAMILY            0.260000
# 4      1682665200000      SINGLE_FAMILY            0.920000
# ...              ...                ...                 ...
# 4535   1646035200000      SINGLE_FAMILY            0.250000
# 4536   1646035200000      SINGLE_FAMILY         9583.000000
# 4537   1646035200000      SINGLE_FAMILY         5662.800000
# 4538   1645776000000      SINGLE_FAMILY            1.720000
# 4539   1645776000000      SINGLE_FAMILY            1.720000
#
#                                      props.address props.variableData.text  \
# 0          7525 Matherly Dr, Wake Forest, NC 27587         Sold 04/28/2023
# ...

# %%
# Get datatypes
zillow_wake_co_df.dtypes
# Out:
# props.dateSold                   int64
# props.propertyType              object
# props.lotAreaValue             float64
# props.address                   object
# props.variableData.text         object
# props.variableData.type         object
# props.zestimate                float64
# props.imgSrc                    object
# props.price                      int64
# props.bedrooms                 float64
# props.contingentListingType     object
# props.longitude                float64
# props.latitude                 float64
# props.listingStatus             object
# props.zpid                       int64
# props.rentZestimate              int64
# props.daysOnZillow               int64
# props.bathrooms                float64
# props.livingArea               float64
# props.country                   object
# props.currency                  object
# props.lotAreaUnit               object
# props.hasImage                  object
# Unnamed: 23                    float64
# ...

# %%
# Counting Nan/null in above columns
print("\nCount total Nan at each column in a Dataframe : \n\n", zillow_wake_co_df.isnull().sum())
# Out:
# Count total Nan at each column in a Dataframe :
#
#  props.dateSold                    0
# props.propertyType                0
# props.lotAreaValue                0
# props.address                     0
# props.variableData.text           0
# props.variableData.type           0
# props.zestimate                   3
# props.imgSrc                      0
# props.price                       0
# props.bedrooms                   30
# props.contingentListingType    4443
# props.longitude                   8
# props.latitude                    8
# props.listingStatus               0
# props.zpid                        0
# props.rentZestimate               0
# props.daysOnZillow                0
# props.bathrooms                   5
# props.livingArea                  4
# props.country                     0
# props.currency                    0
# props.lotAreaUnit                 0
# props.hasImage                   52
# Unnamed: 23                    4538
# ...

# %%
#drop unnecessary columns starting Unnamed: 23,24,25
zillow_wake_co_df = zillow_wake_co_df.drop(columns =['Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25'])

# %%
#Check new dataframe columns
zillow_wake_co_df.dtypes
# Out:
# props.dateSold                   int64
# props.propertyType              object
# props.lotAreaValue             float64
# props.address                   object
# props.variableData.text         object
# props.variableData.type         object
# props.zestimate                float64
# props.imgSrc                    object
# props.price                      int64
# props.bedrooms                 float64
# props.contingentListingType     object
# props.longitude                float64
# props.latitude                 float64
# props.listingStatus             object
# props.zpid                       int64
# props.rentZestimate              int64
# props.daysOnZillow               int64
# props.bathrooms                float64
# props.livingArea               float64
# props.country                   object
# props.currency                  object
# props.lotAreaUnit               object
# props.hasImage                  object
# dtype: object

# %%
# Saved file to csv
zillow_wake_co_df.to_csv("zillow_wake_co_df.csv", index=False, encoding = 'utf8')
